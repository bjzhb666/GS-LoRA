# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8')
plt.rc('font',family='Times New Roman')
# 数据
fig, (ax1,ax2) = plt.subplots(1,2,sharey=False, figsize=(10, 4))
x = range(1, 8)  # x轴数据
before = [0.4469, 0.4498, 0.449, 0.4112, 0.4104, 0.409, 0.429]
ours = [0.4415, 0.4464, 0.4201, 0.4322, 0.4004, 0.4186, 0.4364]
L2 = [0.3562, 0.3685, 0.3729, 0.3525, 0.3444, 0.3447, 0.3895]

EWC = [0.3360, 0.3382, 0.3469, 0.3211, 0.3295, 0.3593, 0.3345]
MAS= [0.3235, 0.3132, 0.3201, 0.2970, 0.3191, 0.3094, 0.3421]

before = [i * 100 for i in before]
ours = [i * 100 for i in ours]
L2 = [i * 100 for i in L2]
EWC = [i * 100 for i in EWC]
MAS = [i * 100 for i in MAS]

# 绘制折线图
ax1.plot(x, before, marker='o', label='Pre-train',linestyle=':',color='#1f77b4')
ax1.plot(x, L2, marker='v', label=r'L2$^*$',color='#ff7f0e')
ax1.plot(x, EWC, marker='s', label=r'EWC$^*$',color='#2ca02c')
ax1.plot(x, MAS, marker='*', label=r'MAS$^*$',color='#9467bd')#9467bd
ax1.plot(x, ours, marker='d', label='GS-LoRA',color='#d62728')

# 添加标题和图注
# plt.title('Comparison of mAP for remained classes')
ax1.set_xlabel('Task',fontsize=20)
ax1.set_ylabel('AP',fontsize=20)
# ax1.grid(True, linestyle=':', alpha=1)
# 显示图例
# ax1.legend(ncol=5, loc='lower center',bbox_to_anchor=(0, -0.3),fontsize=10)
# ax1.set_yticks([],fontsize=20)
ax1.set_xticks([1,2,3,4,5,6,7])
ax1.set_xticklabels(['1','2','3','4','5','6','7'],fontsize=20)
ax1.set_yticks([30,32,34,36,38,40,42,44])
ax1.set_yticklabels(['30','32','34','36','38','40','42','44'],fontsize=20)
ax1.set_title('AP for retained classes',fontsize=20)

before = [0.4392, 0.4145, 0.4452, 0.4774, 0.5183, 0.4032, 0.4254]
ours = [0.0347, 0.0394, 0.0777, 0.0688, 0.0020, 0.0133, 0.0284]
L2 = [0.2131, 0.2409, 0.2646, 0.3215, 0.2836, 0.2576, 0.2694]
EWC = [0.1266, 0.1185, 0.1590, 0.1218, 0.2118, 0.1925, 0.2007]
MAS = [0.1186, 0.0720, 0.1150, 0.1075, 0.2326, 0.1170, 0.1394]

before = [i * 100 for i in before]
ours = [i * 100 for i in ours]
L2 = [i * 100 for i in L2]
EWC = [i * 100 for i in EWC]
MAS = [i * 100 for i in MAS]


# 绘制折线图
plt.plot(x, before, marker='o', label='Pre-train',linestyle=':',color='#1f77b4')
ax2.plot(x, L2, marker='v', label=r'L2$^*$',color='#ff7f0e')
ax2.plot(x, EWC, marker='s', label=r'EWC$^*$',color='#2ca02c')
ax2.plot(x, MAS, marker='*', label=r'MAS$^*$',color='#9467bd')#9467bd
ax2.plot(x, ours, marker='d', label='GS-LoRA',color='#d62728')

# 添加标题和图注

ax2.set_xlabel('Task',fontsize=20)
ax2.set_ylabel('AP',fontsize=20)
# ax2.grid(True, linestyle=':', alpha=1)
# 显示图例
ax1.legend(ncol=5, loc='lower center',bbox_to_anchor=(1, -0.4),fontsize=15)
# ax1.set_yticks([],fontsize=20)
ax2.set_xticks([1,2,3,4,5,6,7])
ax2.set_xticklabels(['1','2','3','4','5','6','7'],fontsize=20)
ax2.set_yticks([0,10,20,30,40,50])
ax2.set_yticklabels(['0','10','20','30','40','50'],fontsize=20)
ax2.set_title('AP for forgotten classes',fontsize=20)

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.3, hspace=None)

plt.savefig('remain.pdf', bbox_inches='tight', dpi=1200)
# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt


# 数据
x = range(1, 8)  # x轴数据
before = [0.4392, 0.4145, 0.4452, 0.4774, 0.5183, 0.4032, 0.4254]
ours = [0.0347, 0.0394, 0.0777, 0.0688, 0.0020, 0.0133, 0.0284]
L2 = [0.2131, 0.2409, 0.2646, 0.3215, 0.2836, 0.2576, 0.2694]
EWC = [0.1266, 0.1185, 0.1590, 0.1218, 0.2118, 0.1925, 0.2007]
MAS = [0.1186, 0.0720, 0.1150, 0.1075, 0.2326, 0.1170, 0.1394]

before = [i * 100 for i in before]
ours = [i * 100 for i in ours]
L2 = [i * 100 for i in L2]
EWC = [i * 100 for i in EWC]
MAS = [i * 100 for i in MAS]

# 绘制折线图
plt.plot(x, before, marker='o', label='Baseline',linestyle=':',color='#1f77b4')
plt.plot(x, L2, marker='v', label=r'L2$^*$',color='#ff7f0e')
plt.plot(x, EWC, marker='s', label=r'EWC$^*$',color='#2ca02c')
plt.plot(x, MAS, marker='*', label=r'MAS$^*$',color='#9467bd')#9467bd
plt.plot(x, ours, marker='d', label='GS-LoRA',color='#d62728')

# 添加标题和图注
# plt.title('Comparison of mAP for remained classes')
plt.xlabel('Task')
plt.ylabel('AP')
plt.grid(True, linestyle=':', alpha=1)
# 显示图例
# plt.legend()
# plt.savefig('forget.pdf')
plt.legend(ncol=5, loc='lower center',bbox_to_anchor=(0.5, -0.22))
# 显示图形
# 单独将图例保存为PDF
plt.savefig('forget.pdf', bbox_inches='tight', dpi=1200)
plt.show()

# %% [markdown]
# H 和old class

# %%
import matplotlib.pyplot as plt

fig, (ax1,ax2) = plt.subplots(1,2,sharey=False, figsize=(10, 4))
# 数据
x = range(2, 8)  # x轴数据
#before = [0.4392, 0.4145, 0.4452, 0.4774, 0.5183, 0.4032, 0.4254]

ours = [0.0577, 0.0419, 0.0694, 0.0521, 0.0333, 0.0312]
L2= [0.2842, 0.2591, 0.2551, 0.2358, 0.2508, 0.2012]
EWC = [0.1789, 0.1562, 0.1334, 0.1840, 0.1751, 0.1525]
MAS = [0.1268, 0.1232, 0.1276, 0.1596, 0.1393, 0.1133]

#before = [i * 100 for i in before]
ours = [i * 100 for i in ours]
L2 = [i * 100 for i in L2]
EWC = [i * 100 for i in EWC]
MAS = [i * 100 for i in MAS]

# 绘制折线图
# ax1.plot(x, before, marker='o', label='Baseline',linestyle=':',color='#1f77b4')
ax1.plot(x, L2, marker='v', label=r'L2$^*$',color='#ff7f0e')
ax1.plot(x, EWC, marker='s', label=r'EWC$^*$',color='#2ca02c')
ax1.plot(x, MAS, marker='*', label=r'MAS$^*$',color='#9467bd')#9467bd
ax1.plot(x, ours, marker='d', label='GS-LoRA',color='#d62728')

# 添加标题和图注
# plt.title('Comparison of mAP for remained classes')
ax1.set_xlabel('Task',fontsize=20)
ax1.set_ylabel('AP',fontsize=20)
# ax1.grid(True, linestyle=':', alpha=1)

ax1.set_xticks([2,3,4,5,6,7])
ax1.set_xticklabels(['2','3','4','5','6','7'],fontsize=20)
ax1.set_yticks([5,10,15,20,25])
ax1.set_yticklabels(['5','10','15','20','25'],fontsize=20)
ax1.set_title('AP for old classes',fontsize=20)

ours= [0.422190898, 0.407655849, 0.39204355, 0.420068792, 0.451023279, 0.403740606,0.415768659
]
L2 = [0.276616246, 0.23601402, 0.243345041, 0.216187057, 0.279159662, 0.204724944, 0.222775435]
EWC = [0.323877891, 0.315695995, 0.31364012, 0.337470548, 0.317584119, 0.26562986, 0.268820279]
MAS = [0.322043472, 0.327195364, 0.325071567, 0.329465587, 0.301477745, 0.297348153, 0.311544658]

#before = [i * 100 for i in before]
x=range(1,8)
ours = [i * 100 for i in ours]
L2 = [i * 100 for i in L2]
EWC = [i * 100 for i in EWC]
MAS = [i * 100 for i in MAS]

# 绘制折线图
# ax1.plot(x, before, marker='o', label='Baseline',linestyle=':',color='#1f77b4')
# ax2.plot(x, before, marker='o', label='Baseline',linestyle=':',color='#1f77b4')
ax2.plot(x, L2, marker='v', label=r'L2$^*$',color='#ff7f0e')
ax2.plot(x, EWC, marker='s', label=r'EWC$^*$',color='#2ca02c')
ax2.plot(x, MAS, marker='*', label=r'MAS$^*$',color='#9467bd')#9467bd
ax2.plot(x, ours, marker='d', label='GS-LoRA',color='#d62728')

ax2.set_xlabel('Task',fontsize=20)
ax2.set_ylabel('AP',fontsize=20)

ax2.set_xticks([1,2,3,4,5,6,7])
ax2.set_xticklabels(['1','2','3','4','5','6','7'],fontsize=20)
ax2.set_yticks([20,25,30,35,40,45])
ax2.set_yticklabels(['20','25','30','35','40','45'],fontsize=20)
ax2.set_title('H Mean',fontsize=20)

ax2.legend(ncol=5, loc='lower center',bbox_to_anchor=(-0.24, -0.4),fontsize=15)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.3, hspace=None)

plt.savefig('old.pdf', bbox_inches='tight', dpi=1200)
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
x = range(1, 8)  # x轴数据
#before = [0.4392, 0.4145, 0.4452, 0.4774, 0.5183, 0.4032, 0.4254]

ours= [0.422190898, 0.407655849, 0.39204355, 0.420068792, 0.451023279, 0.403740606,0.415768659
]
L2 = [0.276616246, 0.23601402, 0.243345041, 0.216187057, 0.279159662, 0.204724944, 0.222775435]
EWC = [0.323877891, 0.315695995, 0.31364012, 0.337470548, 0.317584119, 0.26562986, 0.268820279]
MAS = [0.322043472, 0.327195364, 0.325071567, 0.329465587, 0.301477745, 0.297348153, 0.311544658]

#before = [i * 100 for i in before]
ours = [i * 100 for i in ours]
L2 = [i * 100 for i in L2]
EWC = [i * 100 for i in EWC]
MAS = [i * 100 for i in MAS]


# 绘制折线图
# plt.plot(x, before, marker='o', label='Baseline',linestyle=':',color='#1f77b4')
plt.plot(x, L2, marker='v', label=r'L2$^*$',color='#ff7f0e')
plt.plot(x, EWC, marker='s', label=r'EWC$^*$',color='#2ca02c')
plt.plot(x, MAS, marker='*', label=r'MAS$^*$',color='#9467bd')#9467bd
plt.plot(x, ours, marker='d', label='GS-LoRA',color='#d62728')

# 添加标题和图注
# plt.title('Comparison of mAP for remained classes')
plt.xlabel('Task')
plt.ylabel('mAP')
# 显示网格
plt.grid(True, linestyle=':', alpha=1)
# 显示图例
plt.legend(ncol=4, loc='lower center',bbox_to_anchor=(0.5, -0.22))
# 显示图形
# 单独将图例保存为PDF
plt.savefig('H.pdf', bbox_inches='tight', dpi=1200)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt     
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
